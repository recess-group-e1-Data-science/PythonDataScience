# %%
#importing the necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#setting the maximum rows and columns to display
pd.set_option('display.max_rows',127)
pd.set_option('display.max_columns',38)

# %%
#reading the csv file into a dataframe
all_data = pd.read_csv('2018CrimeStatisticsByCategoryOfCrime.csv',header=None)

# %%
#displaying the dataframe
all_data
# Out:
#         0                      1               2                    3   \
# 0      NaN                    NaN  REPORTED CASES                  NaN
# 1      NaN                    NaN             NaN                  NaN
# 2      NaN                    NaN    Totals Cases  Cases under Inquiry
# 3    S/No.  CASE/CRIME INCIDENCES               1                    2
# 4      NaN              HOMICIDES             NaN                  NaN
# ..     ...                    ...             ...                  ...
# 123     98            UWA Statute             648                  112
# 124     99   Local Government Act               4                    2
# 125    100         All other Acts             821                  345
# 126    NaN  Sub Total(Other Laws)           3,006                  749
# 127    NaN            GRAND TOTAL         238,746               90,763
#
#                    4                     5                          6   \
# ...

# %%
# creating the list of columns names
column_names=[
    #for reported cases
    ('REPORTED CASES','Total Cases'),('REPORTED CASES','Cases under Inquiry'),
    ('REPORTED CASES','Not Detected/NPW'),('REPORTED CASES','Cases taken to court'),
    #for performance
    ('PERFORMANCE','Cases submitted toDPP/RSA'),('PERFORMANCE','Cases with convictions'),
    ('PERFORMANCE','Cases with Acquittals'),('PERFORMANCE','Cases Dismissed'),
    ('PERFORMANCE','Cases pending in Court'),
    #for persons taken to court
    ('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Male Adult'),('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Male Juven.')
    ,('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Female Adult'),('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Female Juven.'),
    ('PERSONS TAKEN TO COURT','ACCUSED CONVICTED','Male Adult'),('PERSONS TAKEN TO COURT','ACCUSED CONVICTED','Male Juven.'),
    ('PERSONS TAKEN TO COURT','ACCUSED CONVICTED','Female Adult'), ('PERSONS TAKEN TO COURT','ACCUSED CONVICTED','Female Juven.'),
    ('PERSONS TAKEN TO COURT','ACCUSED CONVICTED','Acquitted'),('PERSONS TAKEN TO COURT','ACCUSED CONVICTED','Discharged'),
    ('PERSONS TAKEN TO COURT','ACCUSED CONVICTED','Awaiting Trial'),
    #for sentences imposed by courts
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Male Adult'),
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Male Juven.')
    ,('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Female Adult')
    ,('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Female Juven.'),
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Death'),
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Fined'),
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Probation Bound Over'),
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','CAUTION'),
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','COMM. WORK'),
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Fines Awarded (UgShs.)'),
    ('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Male Adult'),
    ('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Male Juven.')
    ,('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Female Adult'),
    ('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Female Juven.'),
    ('SENTENCES IMPOSED BY COURTS','VALUE PROPERTY(UGSHS.)','Lost'),
    ('SENTENCES IMPOSED BY COURTS','VALUE PROPERTY(UGSHS.)','Recovered')
]

# %%
#selecting some from the 4th index row to bottom and 2nd index column to the last one
some_data=all_data.loc[4:,2:]
#displaying the selected columns and rows
some_data
# Out:
#           2       3       4       5        6       7      8       9       10  \
# 4        NaN     NaN     NaN     NaN      NaN     NaN    NaN     NaN     NaN
# 5        190     117      29      44       74       3      1       1      39
# 6        636     431     109      96      176       2      -       1      93
# 7         81      54      12      15       17       -      -       -      15
# 8        362     107      24     231      239      15      -       2     214
# 9         42      25      11       6       14       -      -       -       6
# 10     3,186   1,740     626     820    1,259      25      2       8     785
# 11     4,497   2,474     811   1,212    1,779      45      3      12   1,152
# 12         -       -       -       -        -       -      -       -       -
# 13       199     172      19       8       48       3      -       -       5
# 14        58      49       6       3       18       -      -       -       3
# ...

# %%
# setting the column names as multiIndex 
some_data.columns=pd.MultiIndex.from_tuples(column_names)
#displaying the dataframe
some_data
# Out:
#     REPORTED CASES                                                            \
#        Total Cases Cases under Inquiry Not Detected/NPW Cases taken to court
#                NaN                 NaN              NaN                  NaN
# 4              NaN                 NaN              NaN                  NaN
# 5              190                 117               29                   44
# 6              636                 431              109                   96
# 7               81                  54               12                   15
# 8              362                 107               24                  231
# 9               42                  25               11                    6
# 10           3,186               1,740              626                  820
# 11           4,497               2,474              811                1,212
# 12               -                   -                -                    -
# ...

# %%
# setting the index 
some_data.index=[all_data[0][4:],all_data[1][4:]]
# setting the index names 
some_data.index.names=['S/No.','CASE/CRIME INCIDENCES']
# filling all the Nan values in the column with white space 
some_data.columns= pd.MultiIndex.from_frame(some_data.columns.to_frame().fillna(''))

# %%
#displaying the dataframe
some_data
# Out:
# 0                                                  REPORTED CASES  \
# 1                                                     Total Cases
# 2
# S/No. CASE/CRIME INCIDENCES
# NaN   HOMICIDES                                               NaN
# 1     Death  (by shooting)                                    190
# 2     Death (by mob action)                                   636
# 3     Death (Poisoning)                                        81
# 4     Death (Aggravated Domestic Violence)                    362
# 5     Death(Fire Out Breaks)                                   42
# 8     Other Death (Not Specified above)                     3,186
# NaN   Sub Total(Homicides)                                  4,497
#       ECONOMIC CRIMES                                           -
# 9     Embezzlement                                            199
# 10    Causing Financial losss                                  58
# 11    Abuse of office                                          50
# ...

# %%
# filling all the nan in the index with white space 
some_data.index= pd.MultiIndex.from_frame(some_data.index.to_frame().fillna(''))
# filling the nan in the rest with - to indicate either no value or entering into a different catergory
some_data.fillna('-',inplace=True)
#displaying the dataframe
some_data
# Out:
# 0                                                  REPORTED CASES  \
# 1                                                     Total Cases
# 2
# S/No. CASE/CRIME INCIDENCES
#       HOMICIDES                                                 -
# 1     Death  (by shooting)                                    190
# 2     Death (by mob action)                                   636
# 3     Death (Poisoning)                                        81
# 4     Death (Aggravated Domestic Violence)                    362
# 5     Death(Fire Out Breaks)                                   42
# 8     Other Death (Not Specified above)                     3,186
#       Sub Total(Homicides)                                  4,497
#       ECONOMIC CRIMES                                           -
# 9     Embezzlement                                            199
# 10    Causing Financial losss                                  58
# 11    Abuse of office                                          50
# ...

# %%
# lets first replace all the unused cells with 0
some_data.replace('-',0,inplace=True)
# replacing the commas so as to enable us work with integers
some_data.replace(',','', regex=True, inplace=True)
temp = some_data.select_dtypes(object).columns
some_data[temp] = some_data[temp].apply(pd.to_numeric,errors='coerce')
some_data.abs()
# Out:
# 0                                                  REPORTED CASES  \
# 1                                                     Total Cases
# 2
# S/No. CASE/CRIME INCIDENCES
#       HOMICIDES                                                 0
# 1     Death  (by shooting)                                    190
# 2     Death (by mob action)                                   636
# 3     Death (Poisoning)                                        81
# 4     Death (Aggravated Domestic Violence)                    362
# 5     Death(Fire Out Breaks)                                   42
# 8     Other Death (Not Specified above)                      3186
#       Sub Total(Homicides)                                   4497
#       ECONOMIC CRIMES                                           0
# 9     Embezzlement                                            199
# 10    Causing Financial losss                                  58
# 11    Abuse of office                                          50
# ...

# %%
# filtering the rows that contains only a single value zero and replace it with the original 
some_data[~some_data.any(axis = 1)]='-'
some_data.replace('-','',inplace=True)
#displaying the dataframe
some_data
# Out:
# 0                                                  REPORTED CASES  \
# 1                                                     Total Cases
# 2
# S/No. CASE/CRIME INCIDENCES
#       HOMICIDES
# 1     Death  (by shooting)                                    190
# 2     Death (by mob action)                                   636
# 3     Death (Poisoning)                                        81
# 4     Death (Aggravated Domestic Violence)                    362
# 5     Death(Fire Out Breaks)                                   42
# 8     Other Death (Not Specified above)                      3186
#       Sub Total(Homicides)                                   4497
#       ECONOMIC CRIMES
# 9     Embezzlement                                            199
# 10    Causing Financial losss                                  58
# 11    Abuse of office                                          50
# 12    Counterfeiting                                          541
# ...

# %%
#getting only the homicides total cases
homicides_total_cases = some_data[('REPORTED CASES','Total Cases')].iloc[7:8].astype(int)
#displaying the dataframe
homicides_total_cases
# Out:
# S/No.  CASE/CRIME INCIDENCES
#        Sub Total(Homicides)     4497
# Name: (REPORTED CASES, Total Cases), dtype: int32

# %%
#getting the value from the series
homicides_total_cases = homicides_total_cases[0]
#printing the value
print('Total homicide cases: '+str(homicides_total_cases))
# Out:
# Total homicide cases: 4497

# %%
#getting only the economic crimes total cases
economic_total_cases = some_data[('REPORTED CASES','Total Cases')].iloc[20:21].astype(int)
#displaying the dataframe
economic_total_cases
# Out:
# S/No.  CASE/CRIME INCIDENCES
#        Sub Total(Economic crimes)    15099
# Name: (REPORTED CASES, Total Cases), dtype: int32

# %%
#getting the value from the series
economic_total_cases = economic_total_cases[0]
#printing the value
print('Total economic crimes: '+str(economic_total_cases))
# Out:
# Total economic crimes: 15099

# %%
#getting only the sex related general crimes total cases
sex_related_gen = some_data[('REPORTED CASES','Total Cases')].iloc[28:29].astype(int)
#displaying the dataframe
sex_related_gen
# Out:
# S/No.  CASE/CRIME INCIDENCES
#        Sub Total(Sex Related)    17521
# Name: (REPORTED CASES, Total Cases), dtype: int32

# %%
#getting the value from the series
sex_related_gen = sex_related_gen[0]
#printing the value
print('Total sex related crimes under general crimes: '+str(sex_related_gen))
# Out:
# Total sex related crimes under general crimes: 17521

# %%
#getting only the sex related general crimes total cases
child_related_gen = some_data[('REPORTED CASES','Total Cases')].iloc[38:39].astype(int)
#displaying the dataframe
child_related_gen
# Out:
# S/No.  CASE/CRIME INCIDENCES
#        Sub Total(Child Related)    11589
# Name: (REPORTED CASES, Total Cases), dtype: int32

# %%
#getting the value from the series
child_related_gen = child_related_gen[0]
#printing the value
print('Total child related crimes under general crimes: '+str(child_related_gen))
# Out:
# Total child related crimes under general crimes: 11589

# %%
#getting only the sex related general crimes total cases
breakings_related_gen = some_data[('REPORTED CASES','Total Cases')].iloc[45:46].astype(int)
#displaying the dataframe
breakings_related_gen
# Out:
# S/No.  CASE/CRIME INCIDENCES
#        Sub Total(Breakings)     14018
# Name: (REPORTED CASES, Total Cases), dtype: int32

# %%
#getting the value from the series
breakings_related_gen = breakings_related_gen[0]
#printing the value
print('Total breakings related crimes under general crimes: '+str(breakings_related_gen))
# Out:
# Total breakings related crimes under general crimes: 14018

# %%
#getting only the theft related general crimes total cases
thefts_related_gen = some_data[('REPORTED CASES','Total Cases')].iloc[62:63].astype(int)
#displaying the dataframe
thefts_related_gen
# Out:
# S/No.  CASE/CRIME INCIDENCES
#        Sub Total(Thefts)        61533
# Name: (REPORTED CASES, Total Cases), dtype: int32

# %%
#getting the value from the series
thefts_related_gen = thefts_related_gen[0]
#printing the value
print('Total thefts related crimes under general crimes: '+str(thefts_related_gen))
# Out:
# Total thefts related crimes under general crimes: 61533

# %%
#getting only the theft related general crimes total cases
robberies_related_gen = some_data[('REPORTED CASES','Total Cases')].iloc[70:71].astype(int)
#displaying the dataframe
robberies_related_gen
# Out:
# S/No.  CASE/CRIME INCIDENCES
#        Sub Total(Robberies)     7354
# Name: (REPORTED CASES, Total Cases), dtype: int32

# %%
#getting the value from the series
robberies_related_gen = robberies_related_gen[0]
#printing the value
print('Total robberies related crimes under general crimes: '+str(robberies_related_gen))
# Out:
# Total robberies related crimes under general crimes: 7354

# %%
#getting only the assault related general crimes total cases
assaults_related_gen = some_data[('REPORTED CASES','Total Cases')].iloc[75:76].astype(int)
#displaying the dataframe
assaults_related_gen
# Out:
# S/No.  CASE/CRIME INCIDENCES
#        Sub Total(Assaults)      36323
# Name: (REPORTED CASES, Total Cases), dtype: int32

# %%
#getting the value from the series
assaults_related_gen = assaults_related_gen[0]
#printing the value
print('Total assaults related crimes under general crimes: '+str(assaults_related_gen))
# Out:
# Total assaults related crimes under general crimes: 36323

# %%
#getting only the other crime in  general crimes total cases
other_crimes_gen = some_data[('REPORTED CASES','Total Cases')].iloc[93:94].astype(int)
#displaying the dataframe
other_crimes_gen
# Out:
# S/No.  CASE/CRIME INCIDENCES
#        Sub Total(Other Crimes-gen)    64426
# Name: (REPORTED CASES, Total Cases), dtype: int32

# %%
#getting the value from the series
other_crimes_gen = other_crimes_gen[0]
#printing the value
print('Total of other crimes under general crimes: '+str(other_crimes_gen))
# Out:
# Total of other crimes under general crimes: 64426

# %%
#suming up all the subtotals for  the general crimes to get total general crimes
general_total_cases = sex_related_gen + child_related_gen + breakings_related_gen + thefts_related_gen + robberies_related_gen + assaults_related_gen + other_crimes_gen
print("Total general crimes: "+str(general_total_cases))
# Out:
# Total general crimes: 212764

# %%
#getting only the terriorism crimes total cases
terrorism_total_cases = some_data[('REPORTED CASES','Total Cases')].iloc[97:98].astype(int)
#displaying the dataframe
terrorism_total_cases
# Out:
# S/No.  CASE/CRIME INCIDENCES
#        Sub Total(Terrorism)     16
# Name: (REPORTED CASES, Total Cases), dtype: int32

# %%
#getting the value from the series
terrorism_total_cases = terrorism_total_cases[0]
#printing the value
print('Total of terrorism cases: '+ str(terrorism_total_cases))
# Out:
# Total of terrorism cases: 16

# %%
#getting only the political/media crimes total cases
political_media_total_cases = some_data[('REPORTED CASES','Total Cases')].iloc[103:104].astype(int)
#displaying the dataframe
political_media_total_cases
# Out:
# S/No.  CASE/CRIME INCIDENCES
#        Sub Total(Political/Media)    442
# Name: (REPORTED CASES, Total Cases), dtype: int32

# %%
#getting the value from the series
political_media_total_cases = political_media_total_cases[0]
#printing the value
print('Total of political/media cases: '+ str(political_media_total_cases))
# Out:
# Total of political/media cases: 442

# %%
#getting only the corruption crimes total cases
corruption_total_cases = some_data[('REPORTED CASES','Total Cases')].iloc[106:107].astype(int)
#displaying the dataframe
corruption_total_cases
# Out:
# S/No.  CASE/CRIME INCIDENCES
#        Sub Total (Corruption)    32
# Name: (REPORTED CASES, Total Cases), dtype: int32

# %%
#getting the value from the series
corruption_total_cases = corruption_total_cases[0]
#printing the value
print('Total of corruption cases: '+ str(corruption_total_cases))
# Out:
# Total of corruption cases: 32

# %%
#getting only the nacotic/drug crimes total cases
nacotic_drug_total_cases = some_data[('REPORTED CASES','Total Cases')].iloc[112:113].astype(int)
#displaying the dataframe
nacotic_drug_total_cases
# Out:
# S/No.  CASE/CRIME INCIDENCES
#        Sub Total(Narcotics)     2890
# Name: (REPORTED CASES, Total Cases), dtype: int32

# %%
#getting the value from the series
nacotic_drug_total_cases = nacotic_drug_total_cases[0]
#printing the value
print('Total of nacotic/drug cases: '+ str(nacotic_drug_total_cases))
# Out:
# Total of nacotic/drug cases: 2890

# %%
#getting only the other laws crimes total cases
other_laws_total_cases = some_data[('REPORTED CASES','Total Cases')].iloc[122:123].astype(int)
#displaying the dataframe
other_laws_total_cases
# Out:
# S/No.  CASE/CRIME INCIDENCES
#        Sub Total(Other Laws)    3006
# Name: (REPORTED CASES, Total Cases), dtype: int32

# %%
#getting the value from the series
other_laws_total_cases = other_laws_total_cases[0]
#printing the value
print('Total of other laws cases: '+ str(other_laws_total_cases))
# Out:
# Total of other laws cases: 3006

# %%
labels = ['Sub Total(Homicides)','Sub Total(Economic crimes)','Sub Total(General crimes)','Sub Total(Terrorism)','Sub Total(Political/Media)','Sub Total(Corruption)','Sub Total(Narcotics)','Sub Total(Other Laws)']
values = [homicides_total_cases, economic_total_cases, general_total_cases, terrorism_total_cases, political_media_total_cases, corruption_total_cases, nacotic_drug_total_cases, other_laws_total_cases]

#Creating plot
fig1, ax1 = plt.subplots(figsize=(10,10))
explode = (0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4)
ax1.pie(values, explode=explode, labels=labels, autopct='%1.1f%%', startangle=90,rotatelabels = 90)
patches, texts, auto = ax1.pie(values, shadow=True, startangle=90,explode=explode, autopct='%1.1f%%')

#add justing the position of the legend on the pie char
plt.legend(patches, labels, loc="lower right",bbox_transform=plt.gcf().transFigure)

#setting the title,its position and the fontsize
plt.title('A PIE CHART SHOWING THE PERCENTAGES OF THE SUBTOTAL FOR THE CRIME TYPES', loc='left',fontsize=20)

# show plot
plt.show()

# %%
labels = ['Sub Total(Homicides)','Sub Total(Economic crimes)','Sub Total(General crimes)','Sub Total(Terrorism)','Sub Total(Political/Media)','Sub Total(Corruption)','Sub Total(Narcotics)','Sub Total(Other Laws)']
values = [homicides_total_cases, economic_total_cases, general_total_cases, terrorism_total_cases, political_media_total_cases, corruption_total_cases, nacotic_drug_total_cases, other_laws_total_cases]

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(labels, values, color ='maroon',width = 0.4)
 
plt.xlabel('Sub Totals')
plt.ylabel("No. of cases")
plt.title("A BAR GRAPTH SHOWING THE SUBTOTAL FOR THE CRIME TYPES")
plt.xticks(rotation=90)
plt.show()

# %%
#getting the grand totals for the reported cases
reported_cases_grand = some_data['REPORTED CASES'].iloc[123:124]
#displaying the dataframe
reported_cases_grand
# Out:
# 1                           Total Cases Cases under Inquiry Not Detected/NPW  \
# 2
# S/No. CASE/CRIME INCIDENCES
#       GRAND TOTAL                238746               90763            74948
#
# 1                           Cases taken to court
# 2
# S/No. CASE/CRIME INCIDENCES
#       GRAND TOTAL                          73035

# %%
#plotting a bar graph of the reported cases subtotals
plt.figure()
reported_cases_grand.plot(kind='bar',title='Grand totals for cases Vs how they are handled',xlabel=' Grand Total cases and handling', ylabel='No of cases', subplots=False,figsize=(10,5))
# Out:
# <AxesSubplot:title={'center':'Grand totals for cases Vs how they are handled'}, xlabel=' Grand Total cases and handling', ylabel='No of cases'>

# %%
#getting the performance grand totals
performance_grand_totals = some_data['PERFORMANCE'].iloc[123:124]
#displaying the dataframe
performance_grand_totals
# Out:
# 1                           Cases submitted toDPP/RSA Cases with convictions  \
# 2
# S/No. CASE/CRIME INCIDENCES
#       GRAND TOTAL                              101116                  22263
#
# 1                           Cases with Acquittals Cases Dismissed  \
# 2
# S/No. CASE/CRIME INCIDENCES
#       GRAND TOTAL                            1248           11121
#
# 1                           Cases pending in Court
# 2
# S/No. CASE/CRIME INCIDENCES
#       GRAND TOTAL                            38411

# %%
#plotting a bar graph of the performance grand totals
plt.figure()
performance_grand_totals.plot(kind='bar',title='Total homicide cases Vs how they are handled',xlabel='Total cases and handling', ylabel='No of cases', subplots=False,figsize=(10,5))
# Out:
# <AxesSubplot:title={'center':'Total homicide cases Vs how they are handled'}, xlabel='Total cases and handling', ylabel='No of cases'>

# %%
#getting the victims grand totals
victims_grand_totals=some_data[('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME')].iloc[123:124].astype(int)
#displaying the dataframe
victims_grand_totals
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2901: PerformanceWarning: indexing past lexsort depth may impact performance.
#   result = self._run_cell(
# 2                            Male Adult  Male Juven.  Female Adult  \
# S/No. CASE/CRIME INCIDENCES
#       GRAND TOTAL                143880        10772         60648
#
# 2                            Female Juven.
# S/No. CASE/CRIME INCIDENCES
#       GRAND TOTAL                    24184

# %%
#plotting a bar chart of the grand totals
plt.figure()
victims_grand_totals.plot(kind='bar',title='A bar chart representing the type of victims and their grand totals number',xlabel='Type of victim', ylabel='No of victims', subplots=False,figsize=(10,5))
# Out:
# <AxesSubplot:title={'center':'A bar chart representing the type of victims and their grand totals number'}, xlabel='Type of victim', ylabel='No of victims'>

# %%
#getting the grand total male juven victims only
male_juven_victims_grand=some_data[('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Male Juven.')].iloc[123:124].astype(int)
#getting the grand total male adult victims only
male_adult_victims_grand=some_data[('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Male Adult')].iloc[123:124].astype(int)
#adding the adult and juven victims to get the grand total male victims
total_male_victims_grand = male_juven_victims_grand + male_adult_victims_grand
#getting the value from the series
total_male_victims_grand = total_male_victims_grand[0]
#printing the value
print('Grand Total male victims: '+str(total_male_victims_grand))
# Out:
# Grand Total male victims: 154652

# %%
#getting the grand total female juven victims only
female_juven_victims_grand=some_data[('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Female Juven.')].iloc[123:124].astype(int)
#getting the grand total female adult victims only
female_adult_victims_grand=some_data[('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Female Adult')].iloc[123:124].astype(int)
#adding the adult and juven to get the grand total female victims
total_female_victims_grand = female_juven_victims_grand + female_adult_victims_grand
#getting the value from the series
total_female_victims_grand = total_female_victims_grand[0]
#printing the value
print('Grand Total female victims: '+str(total_female_victims_grand))
# Out:
# Grand Total female victims: 84832

# %%
labels = ['Grand Total Male Victims','Grand Total Female Victims']
values = [total_male_victims_grand,total_female_victims_grand]

#Creating plot
fig1, ax1 = plt.subplots()
explode = (0.2, 0.2,)
ax1.pie(values, explode=explode, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
patches, texts, auto = ax1.pie(values, shadow=True, startangle=90,explode=explode, autopct='%1.1f%%')

#add justing the position of the legend on the pie char
plt.legend(patches, labels, loc="lower right",bbox_transform=plt.gcf().transFigure)

#setting the title,its position and the fontsize
plt.title('A PIE CHART SHOWING THE PERCENTAGES OF THE FEMALE AND MALE VICTIMS GRAND TOTALS', loc='left',fontsize=20)

# show plot
plt.show()

# %%
labels = ['Grand Total Male Victims','Grand Total Female Victims']
values = [total_male_victims_grand,total_female_victims_grand]

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(labels, values, color ='maroon',width = 0.4)
 
plt.xlabel('Grand Totals')
plt.ylabel("No. of cases")
plt.title("A BAR GRAPTH SHOWING THE GRAND TOTALS FOR THE VICTIMS AS PER SEX")
plt.xticks(rotation=90)
plt.show()

# %%
#getting the grand totals of the accused and charged
accused_charged_grand=some_data[('PERSONS TAKEN TO COURT','ACCUSED CHARGED')].iloc[123:124].astype(int)
#displaying the dataframe
accused_charged_grand
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2901: PerformanceWarning: indexing past lexsort depth may impact performance.
#   result = self._run_cell(
# 2                            Male Adult  Male Juven.  Female Adult  \
# S/No. CASE/CRIME INCIDENCES
#       GRAND TOTAL                 79083         2355          5988
#
# 2                            Female Juven.
# S/No. CASE/CRIME INCIDENCES
#       GRAND TOTAL                      596

# %%
#plotting the grand totals on a bar graph
accused_charged_grand.plot.bar(figsize=(10,5),title='A bar graph showing the grand total of accused and charged persons for each sex and age bracket',xlabel='Type of crime',ylabel='No of accused and charged')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#getting the grand total number of male juven accused and charged only
male_accused_charged_juven_grand=some_data[('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Male Juven.')].iloc[123:124].astype(int)
#getting the grand total number of male adult accused and charged only
male_accused_charged_adult_grand=some_data[('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Male Adult')].iloc[123:124].astype(int)
#adding the juven with the adults to get the total male accused charged
total_male_accused_charged_grand = male_accused_charged_juven_grand + male_accused_charged_adult_grand
#getting the value from the series
total_male_accused_charged_grand = total_male_accused_charged_grand[0]
#printing the series
print('Grand Total male accused charged: '+str(total_male_accused_charged_grand))
# Out:
# Grand Total male accused charged: 81438

# %%
#getting the grand total number of female juven accused and charged only
female_accused_charged_juven_grand=some_data[('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Female Juven.')].iloc[123:124].astype(int)
#getting the grand total number of female adult accused and charged only
female_accused_charged_adult_grand=some_data[('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Female Adult')].iloc[123:124].astype(int)
#adding the juven and adult to get the grand total number of female charged accused
total_female_accused_charged_grand = female_accused_charged_juven_grand + female_accused_charged_adult_grand
#getting the value from the series
total_female_accused_charged_grand = total_female_accused_charged_grand[0]
#printing the value
print('Grand Total female accused charged: '+str(total_female_accused_charged_grand))
# Out:
# Grand Total female accused charged: 6584

# %%
labels = ['Grand Total Male Accused Charged','Grand Total Female Accused Charged']
values = [total_male_accused_charged_grand,total_female_accused_charged_grand]

#Creating plot
fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
patches, texts, auto = ax1.pie(values, shadow=True, startangle=90, autopct='%1.1f%%')

#add justing the position of the legend on the pie char
plt.legend(patches, labels, loc="right",bbox_transform=plt.gcf().transFigure)

#setting the title,its position and the fontsize
plt.title('A PIE CHART SHOWING THE PERCENTAGES FOR THE GRAND TOTALS OF THE FEMALE AND MALE ACCUSED CHARGED', loc='left',fontsize=20)

# show plot
plt.show()

# %%
labels = ['Grand Total Male Accused Charged','Grand Total Female Accused Charged']
values = [total_male_accused_charged_grand,total_female_accused_charged_grand]

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(labels, values, color ='maroon',width = 0.4)
 
plt.xlabel('Sub Totals')
plt.ylabel("No. of cases")
plt.title("A BAR GRAPTH SHOWING THE GRAND TOTALS FOR THE ACCUSED AND CHARGED AS PER THE SEX ")
plt.xticks(rotation=90)
plt.show()
