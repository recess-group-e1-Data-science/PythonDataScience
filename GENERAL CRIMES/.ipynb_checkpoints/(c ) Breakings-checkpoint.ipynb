# %%
# The convention is to import pandas shortcut as pd
import pandas as pd
data = pd.read_csv('2018CrimeStatisticsByCategoryOfCrime.csv')

# %%
offence = data.iloc[42:49]

# %%
#printing the Breakings data
offence
# Out:
#    Unnamed: 0                      Unnamed: 1 REPORTED CASES Unnamed: 3  \
# 42        NaN                  (c ) Breakings            NaN        NaN
# 43         34                      Burglaries          6,867      2,256
# 44         35                 House Breakings          3,368      1,038
# 45         36                   Shop Breaking          2,000        670
# 46         37                 Office Breaking            447        223
# 47         38  Other Breakings (garage ,etc )          1,336        368
# 48        NaN            Sub Total(Breakings)         14,018      4,555
#
#    Unnamed: 4 Unnamed: 5 PERFOMANCE Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 42        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 43      1,511      3,100      3,906        851         50        641  ...
# 44        693      1,637      1,933        471         32        321  ...
# 45        390        940      1,224        231         21        181  ...
# ...

# %%
#renameing the columns in the dataframe
offence.columns =['No','Type','Totals Cases','Cases under Inquiry','Not Detected/NPW','Cases taken to court','Cases submitted toDPP/RSA','Cases with convictions','Cases with Acquittals','Cases Dismissed','Cases pending in Court','Male Adult','Male Juven.','Female Adult','Female Juven.','Male Adult','Male Juven.','Female Adult','Female Juven.','Acquitted','Discharged','Awaiting Trial','Male Adult','Male Juven.','Female Adult','Female Juven.','Death','Fined','Probation Bound Over','CAUTION','COMM. WORK','Fines  Awarded (UgShs.)','Male Adult','Male Juven.','Female Adult','Female Juven.','Lost','Recovered']

# %%
offence
# Out:
#      No                            Type Totals Cases Cases under Inquiry  \
# 42  NaN                  (c ) Breakings          NaN                 NaN
# 43   34                      Burglaries        6,867               2,256
# 44   35                 House Breakings        3,368               1,038
# 45   36                   Shop Breaking        2,000                 670
# 46   37                 Office Breaking          447                 223
# 47   38  Other Breakings (garage ,etc )        1,336                 368
# 48  NaN            Sub Total(Breakings)       14,018               4,555
#
#    Not Detected/NPW Cases taken to court Cases submitted toDPP/RSA  \
# 42              NaN                  NaN                       NaN
# 43            1,511                3,100                     3,906
# 44              693                1,637                     1,933
# 45              390                  940                     1,224
# ...

# %%
#removing all the nan values from the dataframe and printing it
offence = offence.fillna('')
offence
# Out:
#     No                            Type Totals Cases Cases under Inquiry  \
# 42                      (c ) Breakings
# 43  34                      Burglaries        6,867               2,256
# 44  35                 House Breakings        3,368               1,038
# 45  36                   Shop Breaking        2,000                 670
# 46  37                 Office Breaking          447                 223
# 47  38  Other Breakings (garage ,etc )        1,336                 368
# 48                Sub Total(Breakings)       14,018               4,555
#
#    Not Detected/NPW Cases taken to court Cases submitted toDPP/RSA  \
# 42
# 43            1,511                3,100                     3,906
# 44              693                1,637                     1,933
# 45              390                  940                     1,224
# 46               84                  140                       210
# 47              264                  704                       818
# ...

# %%
#replacing all the empty cells with 0
offence = offence.replace(to_replace ="-",value =0)
offence
# Out:
#     No                            Type Totals Cases Cases under Inquiry  \
# 42                      (c ) Breakings
# 43  34                      Burglaries        6,867               2,256
# 44  35                 House Breakings        3,368               1,038
# 45  36                   Shop Breaking        2,000                 670
# 46  37                 Office Breaking          447                 223
# 47  38  Other Breakings (garage ,etc )        1,336                 368
# 48                Sub Total(Breakings)       14,018               4,555
#
#    Not Detected/NPW Cases taken to court Cases submitted toDPP/RSA  \
# 42
# 43            1,511                3,100                     3,906
# 44              693                1,637                     1,933
# 45              390                  940                     1,224
# 46               84                  140                       210
# 47              264                  704                       818
# ...
