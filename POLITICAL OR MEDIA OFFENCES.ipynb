# %%
#importing the necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#setting the maximum rows and columns to display
pd.set_option('display.max_rows',127)
pd.set_option('display.max_columns',38)

# %%
#reading the csv file into a dataframe
all_data = pd.read_csv('2018CrimeStatisticsByCategoryOfCrime.csv',header=None)

# %%
#displaying the dataframe
all_data
# Out:
#         0                      1               2                    3   \
# 0      NaN                    NaN  REPORTED CASES                  NaN
# 1      NaN                    NaN             NaN                  NaN
# 2      NaN                    NaN    Totals Cases  Cases under Inquiry
# 3    S/No.  CASE/CRIME INCIDENCES               1                    2
# 4      NaN              HOMICIDES             NaN                  NaN
# ..     ...                    ...             ...                  ...
# 123     98            UWA Statute             648                  112
# 124     99   Local Government Act               4                    2
# 125    100         All other Acts             821                  345
# 126    NaN  Sub Total(Other Laws)           3,006                  749
# 127    NaN            GRAND TOTAL         238,746               90,763
#
#                    4                     5                          6   \
# ...

# %%
# creating the list of columns names
column_names=[
    #for reported cases
    ('REPORTED CASES','Total Cases'),('REPORTED CASES','Cases under Inquiry'),
    ('REPORTED CASES','Not Detected/NPW'),('REPORTED CASES','Cases taken to court'),
    #for performance
    ('PERFORMANCE','Cases submitted toDPP/RSA'),('PERFORMANCE','Cases with convictions'),
    ('PERFORMANCE','Cases with Acquittals'),('PERFORMANCE','Cases Dismissed'),
    ('PERFORMANCE','Cases pending in Court'),
    #for persons taken to court
    ('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Male Adult'),('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Male Juven.')
    ,('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Female Adult'),('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Female Juven.'),
    ('PERSONS TAKEN TO COURT','ACCUSED CONVICTED','Male Adult'),('PERSONS TAKEN TO COURT','ACCUSED CONVICTED','Male Juven.'),
    ('PERSONS TAKEN TO COURT','ACCUSED CONVICTED','Female Adult'), ('PERSONS TAKEN TO COURT','ACCUSED CONVICTED','Female Juven.'),
    ('PERSONS TAKEN TO COURT','ACCUSED CONVICTED','Acquitted'),('PERSONS TAKEN TO COURT','ACCUSED CONVICTED','Discharged'),
    ('PERSONS TAKEN TO COURT','ACCUSED CONVICTED','Awaiting Trial'),
    #for sentences imposed by courts
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Male Adult'),
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Male Juven.')
    ,('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Female Adult')
    ,('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Female Juven.'),
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Death'),
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Fined'),
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Probation Bound Over'),
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','CAUTION'),
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','COMM. WORK'),
    ('SENTENCES IMPOSED BY COURTS','IMPRISONMENT','Fines Awarded (UgShs.)'),
    ('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Male Adult'),
    ('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Male Juven.')
    ,('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Female Adult'),
    ('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Female Juven.'),
    ('SENTENCES IMPOSED BY COURTS','VALUE PROPERTY(UGSHS.)','Lost'),
    ('SENTENCES IMPOSED BY COURTS','VALUE PROPERTY(UGSHS.)','Recovered')
]

# %%
#selecting some from the 4th index row to bottom and 2nd index column to the last one
some_data=all_data.loc[4:,2:]
#displaying the selected columns and rows
some_data
# Out:
#           2       3       4       5        6       7      8       9       10  \
# 4        NaN     NaN     NaN     NaN      NaN     NaN    NaN     NaN     NaN
# 5        190     117      29      44       74       3      1       1      39
# 6        636     431     109      96      176       2      -       1      93
# 7         81      54      12      15       17       -      -       -      15
# 8        362     107      24     231      239      15      -       2     214
# 9         42      25      11       6       14       -      -       -       6
# 10     3,186   1,740     626     820    1,259      25      2       8     785
# 11     4,497   2,474     811   1,212    1,779      45      3      12   1,152
# 12         -       -       -       -        -       -      -       -       -
# 13       199     172      19       8       48       3      -       -       5
# 14        58      49       6       3       18       -      -       -       3
# ...

# %%
# setting the column names as multiIndex 
some_data.columns=pd.MultiIndex.from_tuples(column_names)
#displaying the dataframe
some_data
# Out:
#     REPORTED CASES                                                            \
#        Total Cases Cases under Inquiry Not Detected/NPW Cases taken to court
#                NaN                 NaN              NaN                  NaN
# 4              NaN                 NaN              NaN                  NaN
# 5              190                 117               29                   44
# 6              636                 431              109                   96
# 7               81                  54               12                   15
# 8              362                 107               24                  231
# 9               42                  25               11                    6
# 10           3,186               1,740              626                  820
# 11           4,497               2,474              811                1,212
# 12               -                   -                -                    -
# ...

# %%
# setting the index 
some_data.index=[all_data[0][4:],all_data[1][4:]]
# setting the index names 
some_data.index.names=['S/No.','CASE/CRIME INCIDENCES']
# filling all the Nan values in the column with white space 
some_data.columns= pd.MultiIndex.from_frame(some_data.columns.to_frame().fillna(''))

# %%
#displaying the dataframe
some_data
# Out:
# 0                                                  REPORTED CASES  \
# 1                                                     Total Cases
# 2
# S/No. CASE/CRIME INCIDENCES
# NaN   HOMICIDES                                               NaN
# 1     Death  (by shooting)                                    190
# 2     Death (by mob action)                                   636
# 3     Death (Poisoning)                                        81
# 4     Death (Aggravated Domestic Violence)                    362
# 5     Death(Fire Out Breaks)                                   42
# 8     Other Death (Not Specified above)                     3,186
# NaN   Sub Total(Homicides)                                  4,497
#       ECONOMIC CRIMES                                           -
# 9     Embezzlement                                            199
# 10    Causing Financial losss                                  58
# 11    Abuse of office                                          50
# ...

# %%
# filling all the nan in the index with white space 
some_data.index= pd.MultiIndex.from_frame(some_data.index.to_frame().fillna(''))
# filling the nan in the rest with - to indicate either no value or entering into a different catergory
some_data.fillna('-',inplace=True)
#displaying the dataframe
some_data
# Out:
# 0                                                  REPORTED CASES  \
# 1                                                     Total Cases
# 2
# S/No. CASE/CRIME INCIDENCES
#       HOMICIDES                                                 -
# 1     Death  (by shooting)                                    190
# 2     Death (by mob action)                                   636
# 3     Death (Poisoning)                                        81
# 4     Death (Aggravated Domestic Violence)                    362
# 5     Death(Fire Out Breaks)                                   42
# 8     Other Death (Not Specified above)                     3,186
#       Sub Total(Homicides)                                  4,497
#       ECONOMIC CRIMES                                           -
# 9     Embezzlement                                            199
# 10    Causing Financial losss                                  58
# 11    Abuse of office                                          50
# ...

# %%
# lets first replace all the unused cells with 0
some_data.replace('-',0,inplace=True)
# replacing the commas so as to enable us work with integers
some_data.replace(',','', regex=True, inplace=True)
temp = some_data.select_dtypes(object).columns
some_data[temp] = some_data[temp].apply(pd.to_numeric,errors='coerce')
some_data.abs()
# Out:
# 0                                                  REPORTED CASES  \
# 1                                                     Total Cases
# 2
# S/No. CASE/CRIME INCIDENCES
#       HOMICIDES                                                 0
# 1     Death  (by shooting)                                    190
# 2     Death (by mob action)                                   636
# 3     Death (Poisoning)                                        81
# 4     Death (Aggravated Domestic Violence)                    362
# 5     Death(Fire Out Breaks)                                   42
# 8     Other Death (Not Specified above)                      3186
#       Sub Total(Homicides)                                   4497
#       ECONOMIC CRIMES                                           0
# 9     Embezzlement                                            199
# 10    Causing Financial losss                                  58
# 11    Abuse of office                                          50
# ...

# %%
# filtering the rows that contains only a single value zero and replace it with the original 
some_data[~some_data.any(axis = 1)]='-'
some_data.replace('-','',inplace=True)
#displaying the dataframe
some_data
# Out:
# 0                                                  REPORTED CASES  \
# 1                                                     Total Cases
# 2
# S/No. CASE/CRIME INCIDENCES
#       HOMICIDES
# 1     Death  (by shooting)                                    190
# 2     Death (by mob action)                                   636
# 3     Death (Poisoning)                                        81
# 4     Death (Aggravated Domestic Violence)                    362
# 5     Death(Fire Out Breaks)                                   42
# 8     Other Death (Not Specified above)                      3186
#       Sub Total(Homicides)                                   4497
#       ECONOMIC CRIMES
# 9     Embezzlement                                            199
# 10    Causing Financial losss                                  58
# 11    Abuse of office                                          50
# 12    Counterfeiting                                          541
# ...

# %%
#getting only the political cases and their respective total cases
political_reported_cases = some_data[('REPORTED CASES','Total Cases')].iloc[99:103]
#displaying the dataframe
political_reported_cases
# Out:
# S/No.  CASE/CRIME INCIDENCES
# 82     Incitement to Violence    181
# 83     Promoting Sectariasm        4
# 84     Election Offences         249
# 85     Treason                     8
# Name: (REPORTED CASES, Total Cases), dtype: object

# %%
#describing the dataframe using the describe() method
political_reported_cases.describe()
# Out:
# count       4
# unique      4
# top       181
# freq        1
# Name: (REPORTED CASES, Total Cases), dtype: int64

# %%
#Creating dataset
labels = list(political_reported_cases.keys())
values = political_reported_cases.values.tolist()

#Creating plot
fig1, ax1 = plt.subplots(figsize=(10,5))
explode = (0.1, 0.1, 0.1, 0.1)
ax1.pie(values, explode=explode, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
patches, texts, auto = ax1.pie(values, shadow=True, startangle=90,explode=explode, autopct='%1.1f%%')

#add justing the position of the legend on the pie char
plt.legend(patches, labels, bbox_to_anchor=(1.5,0.5), loc="lower right",bbox_transform=plt.gcf().transFigure)

#setting the title,its position and the fontsize
plt.title('A PIE CHART SHOWING THE DIFFERENT TYPES OF POLITICAL/MEDIA CASES AND THEIR PERCENTAGES', loc='left',fontsize=20)

# show plot
plt.show()

# %%
#getting the all the reported cases
total_performance_stat = some_data['REPORTED CASES'].iloc[99:103].astype(int)
#displaying  the dataframe
total_performance_stat
# Out:
# 1                            Total Cases Cases under Inquiry Not Detected/NPW  \
# 2
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence         181                  81               66
# 83    Promoting Sectariasm             4                   3                0
# 84    Election Offences              249                  97              110
# 85    Treason                          8                   5                0
#
# 1                            Cases taken to court
# 2
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence                   34
# 83    Promoting Sectariasm                      1
# 84    Election Offences                        42
# 85    Treason                                   3

# %%
#describing the dataframe
total_performance_stat.describe()
# Out:
# 1     Total Cases Cases under Inquiry Not Detected/NPW Cases taken to court
# 2
# count    4.000000            4.000000         4.000000             4.000000
# mean   110.500000           46.500000        44.000000            20.000000
# std    123.829183           49.514308        53.888774            21.055482
# min      4.000000            3.000000         0.000000             1.000000
# 25%      7.000000            4.500000         0.000000             2.500000
# 50%     94.500000           43.000000        33.000000            18.500000
# 75%    198.000000           85.000000        77.000000            36.000000
# max    249.000000           97.000000       110.000000            42.000000

# %%
#plotting a bar graph of total_performance
total_performance_stat.plot.bar(figsize=(10,5),title='A bar graph showing the comparison of columns of each individual case type under political/media case',xlabel='Type of crime',ylabel='No Of Cases')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#getting the subtotals for the reported cases
reported_cases_subs = some_data['REPORTED CASES'].iloc[103:104]
#displaying the dataframe
reported_cases_subs
# Out:
# 1                                Total Cases Cases under Inquiry  \
# 2
# S/No. CASE/CRIME INCIDENCES
#       Sub Total(Political/Media)         442                 186
#
# 1                                Not Detected/NPW Cases taken to court
# 2
# S/No. CASE/CRIME INCIDENCES
#       Sub Total(Political/Media)              176                   80

# %%
#plotting a bar graph of the reported cases subtotals
plt.figure()
reported_cases_subs.plot(kind='bar',title='Total political/media cases Vs how they are handled',xlabel='Total cases and handling', ylabel='No of cases', subplots=False,figsize=(10,5))
# Out:
# <AxesSubplot:title={'center':'Total political/media cases Vs how they are handled'}, xlabel='Total cases and handling', ylabel='No of cases'>

# %%
#getting all the columns under performance in the homicides and converting them to integers using astype(int)
performance=some_data['PERFORMANCE'].iloc[99:103].astype(int)
#displaying the dataframe
performance
# Out:
# 1                            Cases submitted toDPP/RSA Cases with convictions  \
# 2
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence                        67                      4
# 83    Promoting Sectariasm                           2                      0
# 84    Election Offences                            101                      5
# 85    Treason                                        4                      0
#
# 1                            Cases with Acquittals Cases Dismissed  \
# 2
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence                     1               7
# 83    Promoting Sectariasm                       0               0
# 84    Election Offences                          2              11
# 85    Treason                                    0               0
#
# 1                            Cases pending in Court
# 2
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence                     22
# ...

# %%
#describing the performance dataframe
performance.describe()
# Out:
# 1     Cases submitted toDPP/RSA Cases with convictions Cases with Acquittals  \
# 2
# count                   4.00000               4.000000              4.000000
# mean                   43.50000               2.250000              0.750000
# std                    48.78866               2.629956              0.957427
# min                     2.00000               0.000000              0.000000
# 25%                     3.50000               0.000000              0.000000
# 50%                    35.50000               2.000000              0.500000
# 75%                    75.50000               4.250000              1.250000
# max                   101.00000               5.000000              2.000000
#
# 1     Cases Dismissed Cases pending in Court
# 2
# count        4.000000               4.000000
# mean         4.500000              12.500000
# std          5.446712              12.179217
# min          0.000000               1.000000
# ...

# %%
#plotting a bar graph using the performance dataframe
performance.plot.bar(figsize=(10,5),title='A bar graph showing the performance for the different political/media cases under each column',xlabel='Crime Category',ylabel='No of Cases')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plotting a correlation graph
performance.corr().plot.bar(title='A bar graph showing the perfomance correlation of political/media cases',ylabel='correlation',xlabel='perfomance')
# Out:
# <AxesSubplot:title={'center':'A bar graph showing the perfomance correlation of political/media cases'}, xlabel='perfomance', ylabel='correlation'>

# %%
#getting the performance subtotals
performance_sub_totals = some_data['PERFORMANCE'].iloc[103:104]
#displaying the dataframe
performance_sub_totals
# Out:
# 1                                Cases submitted toDPP/RSA  \
# 2
# S/No. CASE/CRIME INCIDENCES
#       Sub Total(Political/Media)                       174
#
# 1                                Cases with convictions Cases with Acquittals  \
# 2
# S/No. CASE/CRIME INCIDENCES
#       Sub Total(Political/Media)                      9                     3
#
# 1                                Cases Dismissed Cases pending in Court
# 2
# S/No. CASE/CRIME INCIDENCES
#       Sub Total(Political/Media)              18                     50

# %%
#plotting a bar graph of the performance subtotals
plt.figure()
performance_sub_totals.plot(kind='bar',title='Total political/media cases Vs how they are handled',xlabel='Total cases and handling', ylabel='No of cases', subplots=False,figsize=(10,5))
# Out:
# <AxesSubplot:title={'center':'Total political/media cases Vs how they are handled'}, xlabel='Total cases and handling', ylabel='No of cases'>

# %%
#getting the victims of the homicides
victims=some_data[('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME')].iloc[99:103].astype(int)
#displaying the dataframe
victims
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2901: PerformanceWarning: indexing past lexsort depth may impact performance.
#   result = self._run_cell(
# 2                             Male Adult  Male Juven.  Female Adult  \
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence         171            0            11
# 83    Promoting Sectariasm             4            0             0
# 84    Election Offences              215            1            25
# 85    Treason                          6            0             0
#
# 2                             Female Juven.
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence              0
# 83    Promoting Sectariasm                0
# 84    Election Offences                   0
# 85    Treason                             0

# %%
#describing the dataframe
victims.describe()
# Out:
# 2      Male Adult  Male Juven.  Female Adult  Female Juven.
# count     4.00000         4.00      4.000000            4.0
# mean     99.00000         0.25      9.000000            0.0
# std     110.02121         0.50     11.860298            0.0
# min       4.00000         0.00      0.000000            0.0
# 25%       5.50000         0.00      0.000000            0.0
# 50%      88.50000         0.00      5.500000            0.0
# 75%     182.00000         0.25     14.500000            0.0
# max     215.00000         1.00     25.000000            0.0

# %%
#plotting the victims dataframe on a bar graph
victims.plot.bar(figsize=(10,5),title='A bar graph showing the victims/victim type of each individual case type under political/media cases',xlabel='Type of crime',ylabel='victims')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plotting a correlation graph
victims.corr().plot.bar(title='A bar graph showing the victims correlation of political/media cases',ylabel='correlation',xlabel='victims')
# Out:
# <AxesSubplot:title={'center':'A bar graph showing the victims correlation of political/media cases'}, xlabel='victims', ylabel='correlation'>

# %%
#getting the victims subtotals
victims_sub_totals=some_data[('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME')].iloc[103:104].astype(int)
#displaying the dataframe
victims_sub_totals
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2901: PerformanceWarning: indexing past lexsort depth may impact performance.
#   result = self._run_cell(
# 2                                 Male Adult  Male Juven.  Female Adult  \
# S/No. CASE/CRIME INCIDENCES
#       Sub Total(Political/Media)         396            1            36
#
# 2                                 Female Juven.
# S/No. CASE/CRIME INCIDENCES
#       Sub Total(Political/Media)              0

# %%
#plotting a bar chart of the subtotals
plt.figure()
victims_sub_totals.plot(kind='bar',title='A bar chart representing the type of victims and their total number',xlabel='Type of victim', ylabel='No of victims', subplots=False,figsize=(10,5))
# Out:
# <AxesSubplot:title={'center':'A bar chart representing the type of victims and their total number'}, xlabel='Type of victim', ylabel='No of victims'>

# %%
#getting the total male juven victims only
male_juven_victims=some_data[('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Male Juven.')].iloc[103:104].astype(int)
#getting the total male adult victims only
male_adult_victims=some_data[('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Male Adult')].iloc[103:104].astype(int)
#adding the adult and juven victims to get the total male victims
total_male_victims = male_juven_victims + male_adult_victims
#getting the value from the series
total_male_victims = total_male_victims[0]
#printing the value
print('Total male victims: '+str(total_male_victims))
# Out:
# Total male victims: 397

# %%
#getting the total female juven victims only
female_juven_victims=some_data[('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Female Juven.')].iloc[103:104].astype(int)
#getting the total female adult victims only
female_adult_victims=some_data[('SENTENCES IMPOSED BY COURTS','VICTIMS OF CRIME','Female Adult')].iloc[103:104].astype(int)
#adding the adult and juven to get the total female victims
total_female_victims = female_juven_victims + female_adult_victims
#getting the value from the series
total_female_victims = total_female_victims[0]
#printing the value
print('Total female victims: '+str(total_female_victims))
# Out:
# Total female victims: 36

# %%
labels = ['Total Male Victims','Total Female Victims']
values = [total_male_victims,total_female_victims]

#Creating plot
fig1, ax1 = plt.subplots()
explode = (0.2, 0.2,)
ax1.pie(values, explode=explode, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
patches, texts, auto = ax1.pie(values, shadow=True, startangle=90,explode=explode, autopct='%1.1f%%')

#add justing the position of the legend on the pie char
plt.legend(patches, labels, loc="lower right",bbox_transform=plt.gcf().transFigure)

#setting the title,its position and the fontsize
plt.title('A PIE CHART SHOWING THE PERCENTAGES OF THE FEMALE AND MALE VICTIMS DUE TO POLITICAL/MEDIA CASES', loc='left',fontsize=20)

# show plot
plt.show()

# %%
labels = ['Total Male Victims','Total Female Victims']
values = [total_male_victims,total_female_victims]

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(labels, values, color ='maroon',width = 0.4)
 
plt.xlabel('Sub Totals')
plt.ylabel("No. of cases")
plt.title("A BAR GRAPTH SHOWING THE SUBTOTAL FOR THE VICTIMS AS PER SEX")
plt.xticks(rotation=90)
plt.show()

# %%
#getting the charged acccused persons
accused_charged=some_data[('PERSONS TAKEN TO COURT','ACCUSED CHARGED')].iloc[99:103].astype(int)
#displaying the dataframe
accused_charged
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2901: PerformanceWarning: indexing past lexsort depth may impact performance.
#   result = self._run_cell(
# 2                             Male Adult  Male Juven.  Female Adult  \
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence         126            1             0
# 83    Promoting Sectariasm             3            0             0
# 84    Election Offences               76            1             4
# 85    Treason                         45            0             4
#
# 2                             Female Juven.
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence              0
# 83    Promoting Sectariasm                0
# 84    Election Offences                   0
# 85    Treason                             0

# %%
#describing the dataframe
accused_charged.describe()
# Out:
# 2      Male Adult  Male Juven.  Female Adult  Female Juven.
# count    4.000000      4.00000      4.000000            4.0
# mean    62.500000      0.50000      2.000000            0.0
# std     51.836281      0.57735      2.309401            0.0
# min      3.000000      0.00000      0.000000            0.0
# 25%     34.500000      0.00000      0.000000            0.0
# 50%     60.500000      0.50000      2.000000            0.0
# 75%     88.500000      1.00000      4.000000            0.0
# max    126.000000      1.00000      4.000000            0.0

# %%
#plotting a bar graph of the accuseda charged dataframe
accused_charged.plot.bar(figsize=(10,5),title='A bar graph showing the number of accused and charged persons for each individual case type under political/media',xlabel='Type of crime',ylabel='No of accused and charged')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plotting a correlation graph
accused_charged.corr().plot.bar(title='A bar graph showing the accused charged correlation of political/media cases',ylabel='correlation',xlabel='accused charged')
# Out:
# <AxesSubplot:title={'center':'A bar graph showing the accused charged correlation of political/media cases'}, xlabel='accused charged', ylabel='correlation'>

# %%
#getting the subtotals of the accused and charged
accused_charged_sub=some_data[('PERSONS TAKEN TO COURT','ACCUSED CHARGED')].iloc[103:104].astype(int)
#displaying the dataframe
accused_charged_sub
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2901: PerformanceWarning: indexing past lexsort depth may impact performance.
#   result = self._run_cell(
# 2                                 Male Adult  Male Juven.  Female Adult  \
# S/No. CASE/CRIME INCIDENCES
#       Sub Total(Political/Media)         250            2             8
#
# 2                                 Female Juven.
# S/No. CASE/CRIME INCIDENCES
#       Sub Total(Political/Media)              0

# %%
#plotting the subtotals on a bar graph
accused_charged_sub.plot.bar(figsize=(10,5),title='A bar graph showing the total number of accused and charged persons for each sex and age bracket under political/media cases',xlabel='Type of crime',ylabel='No of accused and charged')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#getting the total number of male juven accused and charged only
male_accused_charged_juven=some_data[('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Male Juven.')].iloc[103:104].astype(int)
#getting the total number of male adult accused and charged only
male_accused_charged_adult=some_data[('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Male Adult')].iloc[103:104].astype(int)
#adding the juven with the adults to get the total male accused charged
total_male_accused_charged = male_accused_charged_juven + male_accused_charged_adult
#getting the value from the series
total_male_accused_charged = total_male_accused_charged[0]
#printing the series
print('Total male accused charged: '+str(total_male_accused_charged))
# Out:
# Total male accused charged: 252

# %%
#getting the total number of female juven accused and charged only
female_accused_charged_juven=some_data[('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Female Juven.')].iloc[103:104].astype(int)
#getting the total number of female adult accused and charged only
female_accused_charged_adult=some_data[('PERSONS TAKEN TO COURT','ACCUSED CHARGED','Female Adult')].iloc[103:104].astype(int)
#adding the juven and adult to get the total number of female charged accused
total_female_accused_charged = female_accused_charged_juven + female_accused_charged_adult
#getting the value from the series
total_female_accused_charged = total_female_accused_charged[0]
#printing the value
print('Total female accused charged: '+str(total_female_accused_charged))
# Out:
# Total female accused charged: 8

# %%
labels = ['Total Male Accused Charged','Total Female Accused Charged']
values = [total_male_accused_charged,total_female_accused_charged]

#Creating plot
fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
patches, texts, auto = ax1.pie(values, shadow=True, startangle=90, autopct='%1.1f%%')

#add justing the position of the legend on the pie char
plt.legend(patches, labels, loc="right",bbox_transform=plt.gcf().transFigure)

#setting the title,its position and the fontsize
plt.title('A PIE CHART SHOWING THE PERCENTAGES OF THE FEMALE AND MALE ACCUSED CHARGED DUE TO POLITICAL/MEDIA CASES', loc='left',fontsize=20)

# show plot
plt.show()

# %%
labels = ['Total Male Accused Charged','Total Female Accused Charged']
values = [total_male_accused_charged,total_female_accused_charged]

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(labels, values, color ='maroon',width = 0.4)
 
plt.xlabel('Sub Totals')
plt.ylabel("No. of cases")
plt.title("A BAR GRAPTH SHOWING THE SUBTOTALS FOR THE ACCUSED AND CHARGED AS PER THE SEX ")
plt.xticks(rotation=90)
plt.show()

# %%
#getting the accused and convicted
accused_convicted=some_data[('PERSONS TAKEN TO COURT','ACCUSED CONVICTED')].iloc[99:103].astype(int)
#displaying the dataframe
accused_convicted
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2901: PerformanceWarning: indexing past lexsort depth may impact performance.
#   result = self._run_cell(
# 2                             Male Adult  Male Juven.  Female Adult  \
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence          18            0             0
# 83    Promoting Sectariasm             0            0             0
# 84    Election Offences                8            1             0
# 85    Treason                          0            0             0
#
# 2                             Female Juven.  Acquitted  Discharged  \
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence              0          1           6
# 83    Promoting Sectariasm                0          0           0
# 84    Election Offences                   0          4          15
# 85    Treason                             0          0           0
#
# 2                             Awaiting Trial
# ...

# %%
#describing the dataframe
accused_convicted.describe()
# Out:
# 2      Male Adult  Male Juven.  Female Adult  Female Juven.  Acquitted  \
# count    4.000000         4.00           4.0            4.0   4.000000
# mean     6.500000         0.25           0.0            0.0   1.250000
# std      8.544004         0.50           0.0            0.0   1.892969
# min      0.000000         0.00           0.0            0.0   0.000000
# 25%      0.000000         0.00           0.0            0.0   0.000000
# 50%      4.000000         0.00           0.0            0.0   0.500000
# 75%     10.500000         0.25           0.0            0.0   1.750000
# max     18.000000         1.00           0.0            0.0   4.000000
#
# 2      Discharged  Awaiting Trial
# count    4.000000        4.000000
# mean     5.250000       51.750000
# std      7.088723       40.458827
# min      0.000000        3.000000
# 25%      0.000000       37.500000
# 50%      3.000000       51.000000
# 75%      8.250000       65.250000
# max     15.000000      102.000000

# %%
#plotting the accused convicted on a bar graph
accused_convicted.plot.bar(figsize=(10,5),title='A bar graph showing the number of accused and convicted persons for each individual case type under political/media',xlabel='Type of crime',ylabel='No accused and convicted')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plotting a correlation graph
accused_convicted.corr().plot.bar(title='A bar graph showing the accused convicted correlation of political/media cases',ylabel='correlation',xlabel='accused convicted')
# Out:
# <AxesSubplot:title={'center':'A bar graph showing the accused convicted correlation of political/media cases'}, xlabel='accused convicted', ylabel='correlation'>

# %%
#getting the subtotals for the accused convicted
accused_convicted_sub=some_data[('PERSONS TAKEN TO COURT','ACCUSED CONVICTED')].iloc[99:103].astype(int)
#displaying the dataframe
accused_convicted_sub
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2901: PerformanceWarning: indexing past lexsort depth may impact performance.
#   result = self._run_cell(
# 2                             Male Adult  Male Juven.  Female Adult  \
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence          18            0             0
# 83    Promoting Sectariasm             0            0             0
# 84    Election Offences                8            1             0
# 85    Treason                          0            0             0
#
# 2                             Female Juven.  Acquitted  Discharged  \
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence              0          1           6
# 83    Promoting Sectariasm                0          0           0
# 84    Election Offences                   0          4          15
# 85    Treason                             0          0           0
#
# 2                             Awaiting Trial
# ...

# %%
#plotting the subtotals of the accused and convicted on the bar graph
accused_convicted_sub.plot.bar(figsize=(10,5),title='A bar graph showing the total number of accused and convicted persons under political/media',xlabel='subtotal',ylabel='No of accused and convicted')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#getting the imprisonments
imprisoned = some_data[('SENTENCES IMPOSED BY COURTS','IMPRISONMENT')].iloc[99:103]
#displaying the dataframe
imprisoned
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2901: PerformanceWarning: indexing past lexsort depth may impact performance.
#   result = self._run_cell(
# 2                            Male Adult Male Juven. Female Adult  \
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence          0           0            0
# 83    Promoting Sectariasm            0           0            0
# 84    Election Offences               0           0            0
# 85    Treason                         0           0            0
#
# 2                            Female Juven. Death Fined Probation Bound Over  \
# S/No. CASE/CRIME INCIDENCES
# 82    Incitement to Violence             0     0     0                    0
# 83    Promoting Sectariasm               0     0     0                    0
# 84    Election Offences                  0     0     2                    0
# 85    Treason                            0     0     0                    0
#
# ...

# %%
#getting the imprisonment subtotals
imprisoned_sub = some_data[('SENTENCES IMPOSED BY COURTS','IMPRISONMENT')].iloc[103:104]
#displaying the dataframe
imprisoned_sub
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2901: PerformanceWarning: indexing past lexsort depth may impact performance.
#   result = self._run_cell(
# 2                                Male Adult Male Juven. Female Adult  \
# S/No. CASE/CRIME INCIDENCES
#       Sub Total(Political/Media)          0           0            0
#
# 2                                Female Juven. Death Fined  \
# S/No. CASE/CRIME INCIDENCES
#       Sub Total(Political/Media)             0     0     2
#
# 2                                Probation Bound Over CAUTION COMM. WORK  \
# S/No. CASE/CRIME INCIDENCES
#       Sub Total(Political/Media)                    0       3         22
#
# 2                                Fines Awarded (UgShs.)
# S/No. CASE/CRIME INCIDENCES
#       Sub Total(Political/Media)                1200000
